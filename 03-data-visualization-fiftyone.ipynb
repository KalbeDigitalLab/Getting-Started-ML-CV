# %% [markdown]
# # FiftyOne Dataset Visualization
#
# [FiftyOne](https://docs.voxel51.com/) provides a dataset visualization tool that allows users to interactively explore and visualize computer vision datasets. With this tool, users can browse through images, view annotations and labels, and gain insights into the dataset. It offers a user-friendly interface that enables interactive exploration of individual samples and supports various visualization techniques, such as overlaying annotations on images and comparing multiple images side by side. The dataset visualization tool in FiftyOne helps researchers and practitioners understand the dataset's content, quality, and distribution, facilitating effective analysis and decision-making during model development.
#
# This guideline will only show you how to load a preconfigured dataset using FiftyOne. A more comprehensive guide will be available later or you will be asked to read the [documentations](https://docs.voxel51.com/), [tutorials](https://docs.voxel51.com/tutorials/index.html), or attend the monthly [workshops](https://voxel51.com/computer-vision-events/)

# %%
# !pip3 install -q 'opencv-python-headless<4.6' fiftyone

# %%
# !export LD_LIBRARY_PATH=$HOME/opt/lib${LD_LIBRARY_PATH:+:${LD_LIBRARY_PATH}}

# %%
import os
import fiftyone as fo

ROOT_DIR = os.path.dirname(os.path.abspath(''))
DATA_DIR = os.path.join(ROOT_DIR, 'data/food-101-tiny')

train_data_path = os.path.join(DATA_DIR, 'train')
val_data_path = os.path.join(DATA_DIR, 'valid')
# Out:
# Migrating database to v0.20.1

# %% [markdown]
# ### Solving Errors
#
# 1. `libcrypto.so.1.1: cannot open shared object file: No such file or directory`:
# ```
# fiftyone/db/bin/mongod: error while loading shared libraries: libcrypto.so.1.1: cannot open shared object file: No such file or directory
# ```
#
# You can solve it by following the instruction from [here](https://stackoverflow.com/a/73604364).
#
# 2. Could not connect to `mongod`:
#
# Follow this [instruction](https://www.mongodb.com/docs/manual/administration/install-on-linux/) on how to install mongodb<6.0
#
# 3. module 'fiftyone' has no attribute 'config'
#
# Follow this [instruction](https://github.com/voxel51/fiftyone/issues/1494#issuecomment-1003148448) to solve the problem
#
# ```
# !pip uninstall -y fiftyone opencv-python-headless
# ### Restart notebook kernels
# !pip install -q opencv-python-headless fiftyone
# ```

# %% [markdown]
# ## Load and Visualize Dataset

# %% [markdown]
# ### Train Set

# %%
dataset = fo.Dataset.from_dir(
    dataset_dir=train_data_path,
    dataset_type=fo.types.ImageClassificationDirectoryTree,
)

session = fo.launch_app(dataset)
# Out:
#  100% |███████████████| 1500/1500 [1.3s elapsed, 0s remaining, 1.2K samples/s]
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# body, html {
#   margin: 0;
#   padding: 0;
#   width: 100%;
# }
#
# #focontainer-9af49944-cee8-4de8-89e5-a6bcf5fee281 {
#   position: relative;
#   height: 800px;
#   display: block !important;
# }
# #foactivate-9af49944-cee8-4de8-89e5-a6bcf5fee281 {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-9af49944-cee8-4de8-89e5-a6bcf5fee281:focus {
#   outline: none;
# }
# #fooverlay-9af49944-cee8-4de8-89e5-a6bcf5fee281 {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
#
# <div id="focontainer-9af49944-cee8-4de8-89e5-a6bcf5fee281">
#    <div id="fooverlay-9af49944-cee8-4de8-89e5-a6bcf5fee281" style="display: none;">
#       <button id="foactivate-9af49944-cee8-4de8-89e5-a6bcf5fee281" >Activate</button>
#    </div>
#    <img src='data:image/jpeg;base64,...' style="width: 100%; max-width: 1387px;"/>
# </div>
#
# <script type="text/javascript">
#    (function() {
#      var container = document.getElementById("focontainer-9af49944-cee8-4de8-89e5-a6bcf5fee281");
#      var overlay = document.getElementById("fooverlay-9af49944-cee8-4de8-89e5-a6bcf5fee281");
#      fetch(`http://localhost:5151/fiftyone`)
#      .then(() => {
#         overlay.addEventListener("click", () => {
#           fetch(`http://localhost:5151/event`, {
#             method: "POST",
#             body: JSON.stringify({
#               event: "reactivate_notebook_cell",
#               data: { subscription: "9af49944-cee8-4de8-89e5-a6bcf5fee281" },
#               subscription: "9af49944-cee8-4de8-89e5-a6bcf5fee281"
#             })
#           })
#         });
#         container.addEventListener("mouseenter", () => overlay.style.display = "block");
#         container.addEventListener("mouseleave", () => overlay.style.display = "none");
#      });
#    })();
# </script>

# %%
# Replace active App instance with screenshot so App state is viewable offline
session.freeze()

# %% [markdown]
# ### Validation Set

# %%
dataset = fo.Dataset.from_dir(
    dataset_dir=val_data_path,
    dataset_type=fo.types.ImageClassificationDirectoryTree,
)

session = fo.launch_app(dataset)
# Out:
#  100% |█████████████████| 500/500 [742.0ms elapsed, 0s remaining, 678.6 samples/s]
# <style>
# @import url("https://fonts.googleapis.com/css2?family=Palanquin&display=swap");
#
# body, html {
#   margin: 0;
#   padding: 0;
#   width: 100%;
# }
#
# #focontainer-ac77d40f-6e4d-4578-884a-20196b098609 {
#   position: relative;
#   height: 800px;
#   display: block !important;
# }
# #foactivate-ac77d40f-6e4d-4578-884a-20196b098609 {
#   font-weight: bold;
#   cursor: pointer;
#   font-size: 24px;
#   border-radius: 3px;
#   text-align: center;
#   padding: 0.5em;
#   color: rgb(255, 255, 255);
#   font-family: "Palanquin", sans-serif;
#   position: absolute;
#   left: 50%;
#   top: 50%;
#   width: 160px;
#   margin-left: -80px;
#   margin-top: -23px;
#   background: hsla(210,11%,15%, 0.8);
#   border: none;
# }
# #foactivate-ac77d40f-6e4d-4578-884a-20196b098609:focus {
#   outline: none;
# }
# #fooverlay-ac77d40f-6e4d-4578-884a-20196b098609 {
#   width: 100%;
#   height: 100%;
#   background: hsla(208, 7%, 46%, 0.7);
#   position: absolute;
#   top: 0;
#   left: 0;
#   display: none;
#   cursor: pointer;
# }
# </style>
#
# <div id="focontainer-ac77d40f-6e4d-4578-884a-20196b098609">
#    <div id="fooverlay-ac77d40f-6e4d-4578-884a-20196b098609" style="display: none;">
#       <button id="foactivate-ac77d40f-6e4d-4578-884a-20196b098609" >Activate</button>
#    </div>
#    <img src='data:image/jpeg;base64,...' style="width: 100%; max-width: 1387px;"/>
# </div>
#
# <script type="text/javascript">
#    (function() {
#      var container = document.getElementById("focontainer-ac77d40f-6e4d-4578-884a-20196b098609");
#      var overlay = document.getElementById("fooverlay-ac77d40f-6e4d-4578-884a-20196b098609");
#      fetch(`http://localhost:5151/fiftyone`)
#      .then(() => {
#         overlay.addEventListener("click", () => {
#           fetch(`http://localhost:5151/event`, {
#             method: "POST",
#             body: JSON.stringify({
#               event: "reactivate_notebook_cell",
#               data: { subscription: "ac77d40f-6e4d-4578-884a-20196b098609" },
#               subscription: "ac77d40f-6e4d-4578-884a-20196b098609"
#             })
#           })
#         });
#         container.addEventListener("mouseenter", () => overlay.style.display = "block");
#         container.addEventListener("mouseleave", () => overlay.style.display = "none");
#      });
#    })();
# </script>

# %%
# Replace active App instance with screenshot so App state is viewable offline
session.freeze()
